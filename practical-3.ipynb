# %% [markdown]
# <a href="https://www.kaggle.com/code/aabhathanki/practical-3?scriptVersionId=143075302" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np

# %% [markdown]
# # To split an array of 14 elements into 3 arrays, each with 2, 4, and 8 elements in the original order

# %%
x = np.array([1,2,3,99,99,3,2,1,6,7,4,5,8,4])
x1, x2, x3 = np.split(x, [2,6])
print(x1, x2, x3)

# %% [markdown]
# # To stack arrays horizontally (column wise)

# %%
a=np.random.randint(1,15,4)
b=np.random.randint(1,15,6)

# Stacking the two arrays horizontally
c = np.hstack((a,b))
print ("Output stacked array :\n ",c)
